# %% [markdown]
# 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Lab_1/Au_nanoparticle_dataset.csv')
df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %%
processed_df = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]
processed_df.head()
# Out:
#    N_total  N_bulk  N_surface    R_avg
# 0     1599    1014        585  17.3706
# 1     1642    1034        608  17.6061
# 2     4637    3365       1272  25.3692
# 3     7189    5292       1897  29.7011
# 4    11004    8508       2496  34.2831

# %% [markdown]
# 2

# %%
processed_df.head(20)
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %% [markdown]
# 3

# %%
processed_df.describe().drop(['count', 'min', 'max']).T
# Out:
#                   mean          std          25%         50%          75%
# N_total    3476.786500  3679.286769  1061.000000  1867.00000  4503.000000
# N_bulk     2521.550250  2976.232459   618.750000  1199.00000  3183.000000
# N_surface   955.236250   721.870220   437.000000   666.00000  1301.750000
# R_avg        20.654363     7.610716    15.160725    18.62925    25.525125

# %% [markdown]
# 4

# %%
figure, axes = plt.subplots(nrows=1, ncols=4, figsize=(20, 5))
figure.suptitle('Histograms of each feature')

N_total = axes[0]
N_bulk = axes[1]
N_surface = axes[2]
R_avg = axes[3]

N_total.hist(df['N_total'], bins=100)
N_total.set_ylabel('Frequency')
N_total.set_title('N_total')

N_bulk.hist(df['N_bulk'], bins=100)
N_bulk.set_title('N_bulk')
N_bulk.set_title('N_total')

N_surface.hist(df['N_surface'], bins=100)
N_surface.set_title('N_surface')
N_surface.set_title('N_total')

R_avg.hist(df['R_avg'], bins=100)
R_avg.set_title('R_avg')
R_avg.set_title('N_total')

plt.show()

# %% [markdown]
# 5, 6

# %%
g = sns.PairGrid(processed_df)
g.map_upper(sns.scatterplot)
g.map_diag(lambda x, **kws: sns.histplot(x, **kws, kde=True))
g.map_lower(sns.kdeplot)
